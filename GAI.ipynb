# %%
N=float(input())
SQR=N**0.5
print(SQR)
# Out:
# 4
# 2.0

# %%
A=input()
B=input()
temp=A
A=B
B=temp
print(A,B)
# Out:
# 2
# 3
# 3 2

# %%
N=int(input())
if N < 0:
  print("Negative")
elif N > 0:
  print("Positive")
else:
  print("Zero")
# Out:
# 5
# Positive

# %%
N=int(input())
if N%2 == 0:
  print("Even")
else:
  print("Odd")
# Out:
# 5
# Odd

# %%
N_str = input()
if N_str == N_str[::-1]:
  print("Palindrome")
else:
  print("Not a Palindrome")
# Out:
# MADAM
# Palindrome

# %%
import pandas as pd
Data={'Name':['Bhupala','Preetham','Pavan'],
      'Age':['21','20','19'],
      'City':['Nandyal','Kurnool','Kadapa']}
df=pd.DataFrame(Data)
df
# Out:
#        Name Age     City
# 0   Bhupala  21  Nandyal
# 1  Preetham  20  Kurnool
# 2     Pavan  19   Kadapa

# %%
df['Age']
# Out:
# 0    21
# 1    20
# 2    19
# Name: Age, dtype: object

# %%
df[df['Age'] > 19]
# Out:
#        Name  Age     City
# 0   Bhupala   21  Nandyal
# 1  Preetham   20  Kurnool
